# %% [markdown]
# <a href="https://colab.research.google.com/github/FatiBuuloloo/E-commerce_Shopper_Behavior_Mining_PrefixSpan_-_Association_Rule-mini_project-012/blob/main/notebooks/Sequential_Pattern_Mining_(SPM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install prefixspan
# Out:
# Collecting prefixspan
#   Downloading prefixspan-0.5.2.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting docopt>=0.6.2 (from prefixspan)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting extratools>=0.8.1 (from prefixspan)
#   Downloading extratools-0.8.2.1.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sortedcontainers>=1.5.10 (from extratools>=0.8.1->prefixspan)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from extratools>=0.8.1->prefixspan) (0.12.1)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Building wheels for collected packages: prefixspan, docopt, extratools
#   Building wheel for prefixspan (setup.py) ... done
#   Created wheel for prefixspan: filename=prefixspan-0.5.2-py3-none-any.whl size=11215 sha256=e5d09d103c598a97f38fd0a315a17e2bd5cb9968a1b2ecfb15965421aefcb3c8
#   Stored in directory: /root/.cache/pip/wheels/72/36/65/f9e2bbe4998ab4cdf6e7a015f38bdbb6925301dcf2cce34a88
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=fe30a7db861869287afa97ee27eaebfc52bce99e782923c577c44a372ee14285
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
#   Building wheel for extratools (setup.py) ... done
#   Created wheel for extratools: filename=extratools-0.8.2.1-py3-none-any.whl size=28865 sha256=480254453586f47a19d171e6e1805fbca65c370cca871bafe7ff1acaaf5228e2
#   Stored in directory: /root/.cache/pip/wheels/0f/ab/1f/a5cf2e0513d68e4ff783d169add0c94235bddf2bb8f3dcd581
# Successfully built prefixspan docopt extratools
# Installing collected packages: sortedcontainers, docopt, extratools, prefixspan
# Successfully installed docopt-0.6.2 extratools-0.8.2.1 prefixspan-0.5.2 sortedcontainers-2.4.0

# %%
import pandas as pd
from prefixspan import PrefixSpan
import plotly.graph_objects as go
from collections import defaultdict

# %%
path1 = '/content/drive/MyDrive/eCommerce behavior data/sequence_event1.json'
path2 = '/content/drive/MyDrive/eCommerce behavior data/sequence_event2.json'

with open(path1, 'r') as f:
    sequence_event1 = json.load(f)
with open(path2, 'r') as f:
    sequence_event2 = json.load(f)
combined_sequence = sequence_event1 + sequence_event2

# %%
len(combined_sequence)
# Out:
# 5974703

# %%
total_event = len(combined_sequence)
min_sup_percentage = 0.001
min_support_count = int(total_event * min_sup_percentage)

# %%
ps = PrefixSpan(combined_sequence)
frequent_patterns = ps.frequent(min_support_count)
frequent_patterns.sort(key=lambda x: x[0], reverse=True)

# %%
for freq, pattern in frequent_patterns[:15]:
    print(f"Frequency: {freq} | Pattern: {pattern}")
# Out:
# Frequency: 1512378 | Pattern: ['view_Unknown']
# Frequency: 1285599 | Pattern: ['view_samsung']
# Frequency: 1051460 | Pattern: ['view_Unknown', 'view_Unknown']
# Frequency: 1002335 | Pattern: ['view_apple']
# Frequency: 971106 | Pattern: ['view_samsung', 'view_samsung']
# Frequency: 791250 | Pattern: ['view_apple', 'view_apple']
# Frequency: 737611 | Pattern: ['view_xiaomi']
# Frequency: 670225 | Pattern: ['view_Unknown', 'view_Unknown', 'view_Unknown']
# Frequency: 583094 | Pattern: ['view_samsung', 'view_samsung', 'view_samsung']
# Frequency: 552483 | Pattern: ['view_xiaomi', 'view_xiaomi']
# Frequency: 467691 | Pattern: ['view_Unknown', 'view_Unknown', 'view_Unknown', 'view_Unknown']
# Frequency: 465025 | Pattern: ['view_apple', 'view_apple', 'view_apple']
# Frequency: 380429 | Pattern: ['view_samsung', 'view_samsung', 'view_samsung', 'view_samsung']
# Frequency: 342071 | Pattern: ['view_Unknown', 'view_Unknown', 'view_Unknown', 'view_Unknown', 'view_Unknown']
# Frequency: 338970 | Pattern: ['view_xiaomi', 'view_xiaomi', 'view_xiaomi']

# %%
business_patterns = [
    (freq, pattern) for freq, pattern in frequent_patterns
    if any('cart' in str(item) or 'purchase' in str(item) for item in pattern)
]

for freq, pattern in business_patterns[:15]:
    print(f"Frequency: {freq} | Pattern: {pattern}")
# Out:
# Frequency: 185786 | Pattern: ['cart_samsung']
# Frequency: 184926 | Pattern: ['view_samsung', 'cart_samsung']
# Frequency: 149358 | Pattern: ['purchase_samsung']
# Frequency: 148934 | Pattern: ['view_samsung', 'purchase_samsung']
# Frequency: 136037 | Pattern: ['cart_apple']
# Frequency: 135572 | Pattern: ['view_apple', 'cart_apple']
# Frequency: 127766 | Pattern: ['cart_samsung', 'view_samsung']
# Frequency: 127086 | Pattern: ['view_samsung', 'cart_samsung', 'view_samsung']
# Frequency: 121635 | Pattern: ['purchase_apple']
# Frequency: 121342 | Pattern: ['view_apple', 'purchase_apple']
# Frequency: 104910 | Pattern: ['cart_samsung', 'purchase_samsung']
# Frequency: 104409 | Pattern: ['view_samsung', 'cart_samsung', 'purchase_samsung']
# Frequency: 94500 | Pattern: ['view_samsung', 'view_samsung', 'cart_samsung']
# Frequency: 92655 | Pattern: ['cart_apple', 'view_apple']
# Frequency: 92293 | Pattern: ['view_apple', 'cart_apple', 'view_apple']

# %%
pattern_dict = {tuple(pat): freq for freq, pat in frequent_patterns}
pattern_dict
# Out:
# {('view_Unknown',): 1512378,
#  ('view_samsung',): 1285599,
#  ('view_Unknown', 'view_Unknown'): 1051460,
#  ('view_apple',): 1002335,
#  ('view_samsung', 'view_samsung'): 971106,
#  ('view_apple', 'view_apple'): 791250,
#  ('view_xiaomi',): 737611,
#  ('view_Unknown', 'view_Unknown', 'view_Unknown'): 670225,
#  ('view_samsung', 'view_samsung', 'view_samsung'): 583094,
#  ('view_xiaomi', 'view_xiaomi'): 552483,
#  ('view_Unknown', 'view_Unknown', 'view_Unknown', 'view_Unknown'): 467691,
#  ('view_apple', 'view_apple', 'view_apple'): 465025,
#  ('view_samsung', 'view_samsung', 'view_samsung', 'view_samsung'): 380429,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 342071,
#  ('view_xiaomi', 'view_xiaomi', 'view_xiaomi'): 338970,
#  ('view_huawei',): 309981,
#  ('view_apple', 'view_apple', 'view_apple', 'view_apple'): 293349,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 261208,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 260333,
#  ('view_xiaomi', 'view_xiaomi', 'view_xiaomi', 'view_xiaomi'): 230665,
#  ('view_huawei', 'view_huawei'): 219575,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 203067,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 194564,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 186900,
#  ('cart_samsung',): 185786,
#  ('view_samsung', 'cart_samsung'): 184926,
#  ('view_bosch',): 179832,
#  ('view_lg',): 179735,
#  ('view_lucente',): 179258,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 164487,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 161554,
#  ('view_oppo',): 149568,
#  ('view_samsung', 'view_xiaomi'): 149563,
#  ('purchase_samsung',): 149358,
#  ('view_samsung', 'purchase_samsung'): 148934,
#  ('view_sony',): 147052,
#  ('view_apple', 'view_samsung'): 140359,
#  ('view_samsung', 'view_apple'): 138578,
#  ('view_cordiant',): 138253,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 136688,
#  ('cart_apple',): 136037,
#  ('view_apple', 'cart_apple'): 135572,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 134263,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 130669,
#  ('view_huawei', 'view_huawei', 'view_huawei'): 129014,
#  ('cart_samsung', 'view_samsung'): 127766,
#  ('view_samsung', 'cart_samsung', 'view_samsung'): 127086,
#  ('view_xiaomi', 'view_samsung'): 124619,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 122708,
#  ('purchase_apple',): 121635,
#  ('view_apple', 'purchase_apple'): 121342,
#  ('view_lucente', 'view_lucente'): 119833,
#  ('view_acer',): 119256,
#  ('view_dauscher',): 110136,
#  ('view_artel',): 110096,
#  ('view_lg', 'view_lg'): 108379,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 107069,
#  ('view_bosch', 'view_bosch'): 105759,
#  ('view_philips',): 105705,
#  ('cart_samsung', 'purchase_samsung'): 104910,
#  ('view_samsung', 'view_huawei'): 104582,
#  ('view_samsung', 'cart_samsung', 'purchase_samsung'): 104409,
#  ('view_elenberg',): 103490,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 102848,
#  ('view_oppo', 'view_oppo'): 98316,
#  ('view_lucente', 'view_Unknown'): 97826,
#  ('view_samsung', 'view_samsung', 'view_xiaomi'): 94909,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 94791,
#  ('view_samsung', 'view_samsung', 'cart_samsung'): 94500,
#  ('view_respect',): 94170,
#  ('view_samsung', 'view_xiaomi', 'view_xiaomi'): 93989,
#  ('view_lenovo',): 93899,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 93279,
#  ('cart_apple', 'view_apple'): 92655,
#  ('view_apple', 'cart_apple', 'view_apple'): 92293,
#  ('view_redmond',): 92199,
#  ('view_sony', 'view_sony'): 91681,
#  ('view_hp',): 91005,
#  ('view_vitek',): 90568,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 88639,
#  ('view_indesit',): 87766,
#  ('purchase_samsung', 'view_samsung'): 87638,
#  ('view_samsung', 'purchase_samsung', 'view_samsung'): 87369,
#  ('view_Unknown', 'view_lucente'): 86630,
#  ('view_apple', 'view_samsung', 'view_samsung'): 85314,
#  ('view_huawei', 'view_huawei', 'view_huawei', 'view_huawei'): 83767,
#  ('view_acer', 'view_acer'): 83172,
#  ('view_samsung', 'view_samsung', 'view_apple'): 82774,
#  ('view_beko',): 81353,
#  ('purchase_apple', 'view_apple'): 81352,
#  ('view_apple', 'purchase_apple', 'view_apple'): 81124,
#  ('view_stels',): 81013,
#  ('view_triangle',): 80569,
#  ('view_apple', 'view_apple', 'view_samsung'): 79824,
#  ('view_huawei', 'view_samsung'): 79332,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 78335,
#  ('view_polaris',): 77522,
#  ('view_xiaomi', 'view_xiaomi', 'view_samsung'): 76775,
#  ('view_samsung', 'view_samsung', 'purchase_samsung'): 76771,
#  ('view_cordiant', 'view_cordiant'): 76556,
#  ('view_xiaomi', 'view_samsung', 'view_samsung'): 76515,
#  ('view_sv',): 76351,
#  ('view_samsung', 'view_apple', 'view_apple'): 76043,
#  ('view_lucente', 'view_lucente', 'view_lucente'): 74518,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 74255,
#  ('view_apple', 'view_xiaomi'): 74242,
#  ('view_xiaomi', 'view_huawei'): 73185,
#  ('view_nokian',): 73161,
#  ('cart_apple', 'purchase_apple'): 72650,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 72636,
#  ('view_apple', 'cart_apple', 'purchase_apple'): 72401,
#  ('view_huawei', 'view_xiaomi'): 72401,
#  ('view_brw',): 71774,
#  ('view_tefal',): 71308,
#  ('view_samsung', 'view_samsung', 'view_huawei'): 71223,
#  ('view_haier',): 70713,
#  ('view_apple', 'view_apple', 'cart_apple'): 69410,
#  ('view_samsung', 'view_Unknown'): 68835,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 68663,
#  ('view_lucente', 'view_Unknown', 'view_Unknown'): 68507,
#  ('view_asus',): 68164,
#  ('view_artel', 'view_artel'): 68056,
#  ('view_samsung', 'view_samsung', 'cart_samsung', 'view_samsung'): 66633,
#  ('view_force',): 65397,
#  ('view_samsung', 'view_huawei', 'view_huawei'): 65340,
#  ('view_xiaomi', 'view_apple'): 64174,
#  ('cart_xiaomi',): 64035,
#  ('view_xiaomi', 'cart_xiaomi'): 63784,
#  ('view_lenovo', 'view_lenovo'): 63582,
#  ('view_samsung', 'view_samsung', 'view_xiaomi', 'view_xiaomi'): 63352,
#  ('view_samsung', 'view_lg'): 63092,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 62726,
#  ('cart_samsung', 'view_samsung', 'view_samsung'): 62441,
#  ('view_samsung', 'cart_samsung', 'view_samsung', 'view_samsung'): 62085,
#  ('cart_samsung', 'purchase_samsung', 'view_samsung'): 61490,
#  ('view_apple', 'view_apple', 'purchase_apple'): 61419,
#  ('view_samsung', 'cart_samsung', 'purchase_samsung', 'view_samsung'): 61218,
#  ('view_samsung', 'view_xiaomi', 'view_xiaomi', 'view_xiaomi'): 60962,
#  ('view_lg', 'view_lg', 'view_lg'): 60879,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 60515,
#  ('view_bosch', 'view_bosch', 'view_bosch'): 60444,
#  ('view_dauscher', 'view_dauscher'): 60433,
#  ('view_samsung', 'view_samsung', 'view_samsung', 'view_xiaomi'): 59936,
#  ('view_samsung', 'view_samsung', 'view_samsung', 'cart_samsung'): 59774,
#  ('view_lucente', 'view_lucente', 'view_Unknown'): 59111,
#  ('view_philips', 'view_philips'): 58565,
#  ('view_Unknown', 'view_Unknown', 'view_lucente'): 58513,
#  ('view_casio',): 58313,
#  ('view_hp', 'view_hp'): 58120,
#  ('view_bts',): 58087,
#  ('view_pioneer',): 57801,
#  ('cart_samsung', 'cart_samsung'): 57623,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 57370,
#  ('view_samsung', 'cart_samsung', 'cart_samsung'): 57265,
#  ('view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei'): 56672,
#  ('view_nokia',): 56241,
#  ('view_oppo', 'view_oppo', 'view_oppo'): 56215,
#  ('view_Unknown', 'view_samsung'): 55726,
#  ('view_samsung', 'view_oppo'): 54414,
#  ('view_lg', 'view_samsung'): 54397,
#  ('view_elenberg', 'view_elenberg'): 54297,
#  ('view_apple', 'view_samsung', 'view_samsung', 'view_samsung'): 54278,
#  ('view_Unknown', 'view_lucente', 'view_Unknown'): 53891,
#  ('view_meizu',): 53641,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 53352,
#  ('view_midea',): 53278,
#  ('view_samsung', 'view_samsung', 'view_samsung', 'view_apple'): 53173,
#  ('purchase_Unknown',): 52423,
#  ('view_samsung', 'view_samsung', 'cart_samsung', 'purchase_samsung'): 52393,
#  ('view_Unknown', 'purchase_Unknown'): 52375,
#  ('view_huawei', 'view_samsung', 'view_samsung'): 52140,
#  ('view_indesit', 'view_indesit'): 52088,
#  ('view_respect', 'view_respect'): 52045,
#  ('view_redmond', 'view_redmond'): 52001,
#  ('view_Unknown', 'view_brw'): 51627,
#  ('view_Unknown', 'view_lucente', 'view_lucente'): 51549,
#  ('view_lucente', 'view_Unknown', 'view_Unknown', 'view_Unknown'): 51366,
#  ('view_baden',): 51061,
#  ('view_apple', 'view_apple', 'view_samsung', 'view_samsung'): 51030,
#  ('view_samsung', 'view_xiaomi', 'view_samsung'): 51024,
#  ('view_Unknown', 'view_sv'): 50873,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 50599,
#  ('view_vitek', 'view_vitek'): 50593,
#  ('purchase_xiaomi',): 50515,
#  ('view_xiaomi', 'purchase_xiaomi'): 50399,
#  ('view_xiaomi', 'view_xiaomi', 'view_samsung', 'view_samsung'): 50353,
#  ('view_lucente', 'view_lucente', 'view_lucente', 'view_lucente'): 50224,
#  ('view_sv', 'view_Unknown'): 49938,
#  ('view_huawei', 'view_xiaomi', 'view_xiaomi'): 49921,
#  ('view_sony', 'view_sony', 'view_sony'): 49808,
#  ('view_scarlett',): 49500,
#  ('view_huawei', 'view_huawei', 'view_samsung'): 49481,
#  ('view_jbl',): 49469,
#  ('view_brw', 'view_Unknown'): 49292,
#  ('view_acer', 'view_acer', 'view_acer'): 49282,
#  ('view_xiaomi', 'view_xiaomi', 'view_xiaomi', 'view_samsung'): 48868,
#  ('view_apple', 'view_apple', 'cart_apple', 'view_apple'): 48850,
#  ('view_samsung', 'view_samsung', 'view_samsung', 'purchase_samsung'): 48706,
#  ('cart_apple', 'purchase_apple', 'view_apple'): 48693,
#  ('view_apple', 'view_apple', 'view_apple', 'view_samsung'): 48605,
#  ('view_apple', 'cart_apple', 'purchase_apple', 'view_apple'): 48534,
#  ('view_xiaomi', 'view_xiaomi', 'view_huawei'): 48426,
#  ('view_nike',): 47962,
#  ('view_samsung', 'view_samsung', 'view_apple', 'view_apple'): 47506,
#  ('view_samsung', 'view_samsung', 'view_samsung', 'view_huawei'): 47484,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 47382,
#  ('view_stels', 'view_stels'): 47379,
#  ('view_yokohama',): 47124,
#  ('view_samsung', 'view_samsung', 'view_huawei', 'view_huawei'): 46994,
#  ('view_xiaomi', 'view_samsung', 'view_samsung', 'view_samsung'): 46794,
#  ('view_huawei', 'view_huawei', 'view_xiaomi'): 46265,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 46135,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 45837,
#  ('view_lucente', 'view_Unknown', 'view_lucente'): 45595,
#  ('view_xiaomi', 'view_huawei', 'view_huawei'): 45125,
#  ('view_samsung', 'view_apple', 'view_samsung'): 45095,
#  ('cart_apple', 'view_apple', 'view_apple'): 44982,
#  ('view_triangle', 'view_triangle'): 44949,
#  ('view_xiaomi', 'view_samsung', 'view_xiaomi'): 44818,
#  ('view_apple', 'cart_apple', 'view_apple', 'view_apple'): 44778,
#  ('view_apple', 'view_apple', 'view_apple', 'cart_apple'): 44270,
#  ('view_beko', 'view_beko'): 44188,
#  ('view_samsung', 'view_samsung', 'purchase_samsung', 'view_samsung'): 44171,
#  ('view_samsung', 'view_apple', 'view_apple', 'view_apple'): 44131,
#  ('view_lucente', 'view_lucente', 'view_Unknown', 'view_Unknown'): 43653,
#  ('view_samsung',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 43619,
#  ('view_asus', 'view_asus'): 43410,
#  ('view_apple', 'view_huawei'): 43215,
#  ('view_Unknown', 'view_Unknown', 'view_Unknown', 'view_lucente'): 43073,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'view_samsung'): 42662,
#  ('cart_xiaomi', 'view_xiaomi'): 42618,
#  ('view_xiaomi', 'cart_xiaomi', 'view_xiaomi'): 42456,
#  ('view_viatti',): 42455,
#  ('view_xiaomi', 'view_Unknown'): 42064,
#  ('view_polaris', 'view_polaris'): 41918,
#  ('view_samsung',
#   'view_samsung',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 41856,
#  ('view_apple', 'view_xiaomi', 'view_xiaomi'): 41739,
#  ('view_samsung', 'view_samsung', 'view_lg'): 41475,
#  ('view_oppo', 'view_samsung'): 41388,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_xiaomi'): 41239,
#  ('view_bts', 'view_Unknown'): 41191,
#  ('view_casio', 'view_casio'): 41178,
#  ('view_Unknown', 'view_lucente', 'view_Unknown', 'view_Unknown'): 40949,
#  ('view_apple', 'view_apple', 'purchase_apple', 'view_apple'): 40903,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_xiaomi',
#   'view_xiaomi'): 40796,
#  ('view_respect', 'view_Unknown'): 40448,
#  ('view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 40424,
#  ('view_samsung', 'view_samsung', 'view_Unknown'): 40409,
#  ('view_apple', 'view_Unknown'): 40274,
#  ('view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei'): 40031,
#  ('view_bosch', 'view_bosch', 'view_bosch', 'view_bosch'): 39985,
#  ('view_Unknown', 'view_bts'): 39935,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'cart_samsung'): 39719,
#  ('view_tefal', 'view_tefal'): 39595,
#  ('view_sokolov',): 39567,
#  ('view_Unknown', 'view_bosch'): 39554,
#  ('view_samsung', 'view_huawei', 'view_huawei', 'view_huawei'): 39526,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 39498,
#  ('view_lg', 'view_lg', 'view_lg', 'view_lg'): 39430,
#  ('view_bosch', 'view_Unknown'): 39379,
#  ('view_Unknown', 'view_Unknown', 'view_brw'): 39378,
#  ('view_Unknown', 'view_Unknown', 'view_lucente', 'view_Unknown'): 39333,
#  ('view_apple', 'view_apple', 'view_xiaomi'): 39310,
#  ('view_Unknown', 'view_respect'): 39232,
#  ('view_lucente', 'view_lucente', 'view_lucente', 'view_Unknown'): 39206,
#  ('cart_apple', 'cart_apple'): 39145,
#  ('view_apple', 'view_apple', 'view_apple', 'purchase_apple'): 39054,
#  ('view_apple', 'cart_apple', 'cart_apple'): 38964,
#  ('view_omabelle',): 38904,
#  ('view_nokian', 'view_nokian'): 38870,
#  ('cart_samsung', 'cart_samsung', 'view_samsung'): 38483,
#  ('view_samsung', 'view_huawei', 'view_samsung'): 38448,
#  ('view_haier', 'view_haier'): 38368,
#  ('view_samsung', 'cart_samsung', 'cart_samsung', 'view_samsung'): 38286,
#  ('view_samsung', 'view_samsung', 'view_oppo'): 38127,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 38048,
#  ('view_Unknown', 'view_xiaomi'): 37943,
#  ('view_artel', 'view_artel', 'view_artel'): 37706,
#  ('view_cordiant', 'view_cordiant', 'view_cordiant'): 37609,
#  ('view_skad',): 37573,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 37491,
#  ('view_lenovo', 'view_lenovo', 'view_lenovo'): 37452,
#  ('view_apple',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 37444,
#  ('cart_samsung', 'view_samsung', 'cart_samsung'): 37425,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 37385,
#  ('view_samsung', 'cart_samsung', 'view_samsung', 'cart_samsung'): 37251,
#  ('view_Unknown', 'view_Unknown', 'view_sv'): 37044,
#  ('view_starline',): 37026,
#  ('view_brw', 'view_Unknown', 'view_Unknown'): 36908,
#  ('view_xiaomi', 'view_oppo'): 36703,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_apple'): 36689,
#  ('view_Unknown', 'view_brw', 'view_Unknown'): 36585,
#  ('cart_samsung', 'view_samsung', 'view_samsung', 'view_samsung'): 36577,
#  ('view_apple', 'view_apple', 'cart_apple', 'purchase_apple'): 36550,
#  ('view_oppo', 'view_xiaomi'): 36485,
#  ('view_braun',): 36475,
#  ('view_sv', 'view_Unknown', 'view_Unknown'): 36469,
#  ('view_samsung',
#   'cart_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 36387,
#  ('view_Unknown', 'view_Unknown', 'view_lucente', 'view_lucente'): 36339,
#  ('view_sv', 'view_sv'): 36142,
#  ('view_samsung', 'view_Unknown', 'view_Unknown'): 36058,
#  ('view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'view_samsung',
#   'view_samsung'): 36002,
#  ('view_apple', 'view_samsung', 'view_apple'): 35958,
#  ('view_oppo', 'view_oppo', 'view_oppo', 'view_oppo'): 35838,
#  ('view_samsung', 'view_lg', 'view_lg'): 35740,
#  ('view_karcher',): 35696,
#  ('view_xiaomi', 'view_xiaomi', 'cart_xiaomi'): 35669,
#  ('view_pioneer', 'view_pioneer'): 35613,
#  ('view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente'): 35470,
#  ('view_samsung', 'view_samsung', 'view_xiaomi', 'view_samsung'): 35134,
#  ('view_xiaomi', 'view_xiaomi', 'view_apple'): 34990,
#  ('view_panasonic',): 34986,
#  ('view_meizu', 'view_meizu'): 34982,
#  ('view_vivo',): 34956,
#  ('view_Unknown', 'view_sv', 'view_Unknown'): 34889,
#  ('view_lg', 'view_samsung', 'view_samsung'): 34862,
#  ('view_force', 'view_force'): 34800,
#  ('cart_samsung', 'cart_samsung', 'purchase_samsung'): 34760,
#  ('view_huawei', 'view_apple'): 34757,
#  ('view_huawei', 'view_huawei', 'view_samsung', 'view_samsung'): 34648,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_samsung'): 34592,
#  ('view_samsung', 'cart_samsung', 'cart_samsung', 'purchase_samsung'): 34566,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 34226,
#  ('view_huawei', 'view_huawei', 'view_xiaomi', 'view_xiaomi'): 34178,
#  ('view_huawei', 'view_xiaomi', 'view_xiaomi', 'view_xiaomi'): 34164,
#  ('view_acer', 'view_lenovo'): 33988,
#  ('view_huawei', 'view_samsung', 'view_samsung', 'view_samsung'): 33965,
#  ('view_brw', 'view_brw'): 33962,
#  ('view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 33847,
#  ('view_nokia', 'view_nokia'): 33768,
#  ('view_Unknown', 'view_lucente', 'view_lucente', 'view_lucente'): 33573,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_huawei'): 33558,
#  ('view_xiaomi', 'view_apple', 'view_apple'): 33547,
#  ('view_acer', 'view_acer', 'view_acer', 'view_acer'): 33451,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente'): 33431,
#  ('view_rowenta',): 33287,
#  ('view_apple',
#   'view_apple',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 33286,
#  ('view_hp', 'view_hp', 'view_hp'): 33197,
#  ('view_Unknown', 'view_lucente', 'view_lucente', 'view_Unknown'): 33188,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'purchase_samsung'): 33166,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_samsung',
#   'view_samsung'): 33042,
#  ('view_matador',): 33032,
#  ('view_samsung', 'view_xiaomi', 'view_samsung', 'view_samsung'): 32979,
#  ('view_Unknown', 'view_Unknown', 'purchase_Unknown'): 32757,
#  ('view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 32599,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'purchase_samsung'): 32504,
#  ('view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 32449,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_huawei',
#   'view_huawei'): 32328,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_samsung'): 32269,
#  ('view_xiaomi', 'view_xiaomi', 'view_huawei', 'view_huawei'): 32154,
#  ('view_samsung',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 32144,
#  ('view_xiaomi', 'view_xiaomi', 'view_xiaomi', 'view_huawei'): 32127,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_samsung',
#   'view_samsung'): 31894,
#  ('view_apple', 'view_apple', 'view_apple', 'cart_apple', 'view_apple'): 31839,
#  ('view_xiaomi',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 31759,
#  ('view_lucente', 'view_Unknown', 'view_Unknown', 'view_lucente'): 31625,
#  ('purchase_samsung', 'view_samsung', 'view_samsung'): 31612,
#  ('view_samsung', 'view_samsung', 'cart_samsung', 'cart_samsung'): 31548,
#  ('view_samsung', 'purchase_samsung', 'view_samsung', 'view_samsung'): 31532,
#  ('view_xiaomi', 'view_huawei', 'view_xiaomi'): 31520,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_apple',
#   'view_apple'): 31495,
#  ('view_kenwood',): 31374,
#  ('view_bts', 'view_Unknown', 'view_Unknown'): 31307,
#  ('view_honor',): 31298,
#  ('view_sony', 'view_sony', 'view_sony', 'view_sony'): 31274,
#  ('view_Unknown', 'view_apple'): 31175,
#  ('view_dauscher', 'view_dauscher', 'view_dauscher'): 31175,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown'): 31170,
#  ('view_oppo', 'view_huawei'): 31081,
#  ('view_xiaomi', 'view_samsung', 'view_xiaomi', 'view_xiaomi'): 31063,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 31056,
#  ('view_lucente', 'view_lucente', 'view_Unknown', 'view_lucente'): 30980,
#  ('view_Unknown', 'view_samsung', 'view_samsung'): 30977,
#  ('view_lucente', 'view_Unknown', 'view_lucente', 'view_Unknown'): 30964,
#  ('view_xiaomi', 'view_xiaomi', 'view_samsung', 'view_xiaomi'): 30949,
#  ('view_indesit', 'view_indesit', 'view_indesit'): 30890,
#  ('view_hansa',): 30879,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 30794,
#  ('view_samsung', 'view_huawei', 'view_xiaomi'): 30665,
#  ('view_lenovo', 'view_acer'): 30663,
#  ('view_Unknown', 'view_Unknown', 'view_Unknown', 'view_brw'): 30633,
#  ('view_samsung',
#   'view_samsung',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 30567,
#  ('view_rieker',): 30558,
#  ('view_lg', 'view_lg', 'view_samsung'): 30323,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown'): 30310,
#  ('view_respect', 'view_respect', 'view_respect'): 30230,
#  ('view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'purchase_samsung',
#   'view_samsung'): 30103,
#  ('view_huawei', 'view_huawei', 'view_huawei', 'view_samsung'): 29937,
#  ('view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown'): 29862,
#  ('view_atlant',): 29861,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 29847,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 29792,
#  ('view_samsung', 'view_xiaomi', 'view_xiaomi', 'view_samsung'): 29767,
#  ('view_lucente', 'view_Unknown', 'view_lucente', 'view_lucente'): 29671,
#  ('view_nexpero',): 29557,
#  ('view_philips', 'view_philips', 'view_philips'): 29512,
#  ('view_samsung', 'view_samsung', 'view_apple', 'view_samsung'): 29462,
#  ('view_samsung', 'view_sony'): 29445,
#  ('view_galaxy',): 29378,
#  ('view_force', 'view_stels'): 29366,
#  ('view_apple', 'view_apple', 'view_apple', 'view_apple', 'cart_apple'): 29333,
#  ('view_Unknown', 'view_Unknown', 'view_bts'): 29330,
#  ('view_Unknown', 'view_bts', 'view_Unknown'): 29210,
#  ('view_samsung', 'view_oppo', 'view_oppo'): 29112,
#  ('cart_samsung', 'view_samsung', 'purchase_samsung'): 29072,
#  ('view_Unknown', 'view_Unknown', 'view_brw', 'view_Unknown'): 29061,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 29050,
#  ('view_stels', 'view_Unknown'): 29038,
#  ('view_redmond', 'view_redmond', 'view_redmond'): 29005,
#  ('view_xiaomi', 'view_xiaomi', 'purchase_xiaomi'): 28960,
#  ('view_huawei', 'view_oppo'): 28906,
#  ('view_samsung',
#   'view_samsung',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei'): 28872,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_xiaomi'): 28831,
#  ('view_samsung', 'view_xiaomi', 'view_huawei'): 28809,
#  ('view_samsung', 'cart_samsung', 'view_samsung', 'purchase_samsung'): 28758,
#  ('purchase_Unknown', 'view_Unknown'): 28749,
#  ('view_Unknown', 'purchase_Unknown', 'view_Unknown'): 28710,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_xiaomi',
#   'view_xiaomi'): 28704,
#  ('view_samsung', 'view_apple', 'view_samsung', 'view_samsung'): 28642,
#  ('view_electrolux',): 28633,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'view_samsung'): 28606,
#  ('view_brw', 'view_Unknown', 'view_Unknown', 'view_Unknown'): 28582,
#  ('view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei'): 28555,
#  ('view_midea', 'view_midea'): 28469,
#  ('view_Unknown', 'view_brw', 'view_Unknown', 'view_Unknown'): 28358,
#  ('view_samsung',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 28289,
#  ('view_samsung',
#   'view_samsung',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 28012,
#  ('view_maxwell',): 28002,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'cart_samsung'): 28001,
#  ('view_Unknown', 'view_Unknown', 'view_samsung'): 27963,
#  ('view_stels', 'view_force'): 27880,
#  ('view_Unknown', 'view_Unknown', 'view_Unknown', 'view_sv'): 27867,
#  ('view_sv', 'view_Unknown', 'view_Unknown', 'view_Unknown'): 27713,
#  ('view_samsung', 'view_samsung', 'view_huawei', 'view_samsung'): 27686,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'purchase_samsung',
#   'view_samsung'): 27673,
#  ('view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown'): 27673,
#  ('view_oppo', 'view_samsung', 'view_samsung'): 27639,
#  ('view_bosch', 'view_bosch', 'view_bosch', 'view_bosch', 'view_bosch'): 27591,
#  ('view_huawei', 'view_huawei', 'view_huawei', 'view_xiaomi'): 27578,
#  ('view_Unknown', 'view_lucente', 'view_Unknown', 'view_lucente'): 27542,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 27496,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente'): 27466,
#  ('view_acer', 'view_hp'): 27454,
#  ('view_Unknown', 'view_pioneer'): 27423,
#  ('view_crown',): 27398,
#  ('view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 27332,
#  ('cart_xiaomi', 'purchase_xiaomi'): 27255,
#  ('view_samsung', 'view_samsung', 'view_samsung', 'view_lg'): 27173,
#  ('view_xiaomi', 'cart_xiaomi', 'purchase_xiaomi'): 27145,
#  ('purchase_apple', 'view_apple', 'view_apple'): 27136,
#  ('cart_apple', 'view_apple', 'view_apple', 'view_apple'): 27086,
#  ('view_apple', 'purchase_apple', 'view_apple', 'view_apple'): 27068,
#  ('view_huter',): 27032,
#  ('view_xiaomi', 'view_samsung', 'view_samsung', 'view_xiaomi'): 26997,
#  ('view_apple', 'cart_apple', 'view_apple', 'view_apple', 'view_apple'): 26987,
#  ('view_jbl', 'view_jbl'): 26977,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente'): 26825,
#  ('view_kivi',): 26823,
#  ('view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 26819,
#  ('view_stels', 'view_stels', 'view_stels'): 26784,
#  ('view_samsung', 'view_lg', 'view_samsung'): 26771,
#  ('view_samsung', 'view_bosch'): 26688,
#  ('view_Unknown', 'view_Unknown', 'view_sv', 'view_Unknown'): 26639,
#  ('view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 26615,
#  ('view_lg', 'view_lg', 'view_lg', 'view_lg', 'view_lg'): 26599,
#  ('view_casio', 'view_casio', 'view_casio'): 26599,
#  ('view_samsung',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei'): 26595,
#  ('view_apple',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 26581,
#  ('view_tunga',): 26514,
#  ('view_Unknown', 'view_sv', 'view_Unknown', 'view_Unknown'): 26498,
#  ('view_elari',): 26429,
#  ('cart_huawei',): 26351,
#  ('cart_apple', 'cart_apple', 'view_apple'): 26338,
#  ('view_xiaomi', 'view_huawei', 'view_huawei', 'view_huawei'): 26306,
#  ('view_huawei', 'cart_huawei'): 26266,
#  ('view_apple', 'cart_apple', 'cart_apple', 'view_apple'): 26241,
#  ('view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente'): 26224,
#  ('view_dauscher', 'view_Unknown'): 26203,
#  ('view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown'): 26195,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_apple'): 26134,
#  ('view_samsung', 'view_samsung', 'view_samsung', 'view_oppo'): 26105,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'purchase_apple',
#   'view_apple'): 26047,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 26043,
#  ('view_aeroforce',): 26006,
#  ('view_samsung', 'view_huawei', 'view_samsung', 'view_samsung'): 25986,
#  ('view_cordiant', 'view_Unknown'): 25984,
#  ('view_apple', 'view_apple', 'cart_apple', 'view_apple', 'view_apple'): 25913,
#  ('cart_samsung', 'view_samsung', 'cart_samsung', 'view_samsung'): 25913,
#  ('view_samsung',
#   'cart_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'view_samsung'): 25794,
#  ('view_acer', 'view_asus'): 25778,
#  ('view_scarlett', 'view_scarlett'): 25748,
#  ('view_vitek', 'view_vitek', 'view_vitek'): 25686,
#  ('view_samsung', 'view_samsung', 'view_lg', 'view_lg'): 25678,
#  ('view_lenovo', 'view_lenovo', 'view_lenovo', 'view_lenovo'): 25677,
#  ('view_samsung', 'view_samsung', 'view_samsung', 'view_Unknown'): 25585,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'purchase_apple'): 25538,
#  ('view_huawei',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 25502,
#  ('view_oppo', 'view_xiaomi', 'view_xiaomi'): 25467,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 25451,
#  ('view_gorenje',): 25451,
#  ('view_apple', 'view_xiaomi', 'view_xiaomi', 'view_xiaomi'): 25405,
#  ('view_zeta',): 25347,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 25321,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_samsung'): 25293,
#  ('view_Unknown', 'view_sokolov'): 25213,
#  ('view_ritmix',): 25208,
#  ('view_lider',): 25171,
#  ('view_elenberg', 'view_elenberg', 'view_elenberg'): 25042,
#  ('view_garmin',): 25030,
#  ('purchase_xiaomi', 'view_xiaomi'): 24940,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown'): 24923,
#  ('view_xiaomi', 'purchase_xiaomi', 'view_xiaomi'): 24888,
#  ('view_samsung',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 24840,
#  ('view_baden', 'view_Unknown'): 24835,
#  ('view_xiaomi', 'view_xiaomi', 'view_oppo'): 24777,
#  ('view_prestigio',): 24682,
#  ('view_vivo', 'view_vivo'): 24681,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown'): 24648,
#  ('view_lucente',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown'): 24562,
#  ('view_apple',
#   'view_apple',
#   'cart_apple',
#   'purchase_apple',
#   'view_apple'): 24543,
#  ('view_xiaomi', 'view_xiaomi', 'cart_xiaomi', 'view_xiaomi'): 24530,
#  ('view_bts', 'view_Unknown', 'view_Unknown', 'view_Unknown'): 24450,
#  ('view_baden', 'view_baden'): 24414,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_brw'): 24403,
#  ('view_cantra',): 24360,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente'): 24311,
#  ('view_yokohama', 'view_yokohama'): 24292,
#  ('view_michelin',): 24289,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown'): 24244,
#  ('cart_samsung', 'view_samsung', 'cart_samsung', 'purchase_samsung'): 24243,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'view_samsung',
#   'view_samsung'): 24216,
#  ('view_xiaomi', 'view_xiaomi', 'view_xiaomi', 'cart_xiaomi'): 24208,
#  ('view_apple', 'view_huawei', 'view_huawei'): 24193,
#  ('view_asus', 'view_asus', 'view_asus'): 24161,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 24140,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_samsung',
#   'view_samsung'): 24130,
#  ('view_samsung',
#   'cart_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'purchase_samsung'): 24126,
#  ('view_bosch', 'view_Unknown', 'view_Unknown'): 24122,
#  ('view_huawei',
#   'view_huawei',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 24096,
#  ('view_lenovo', 'view_hp'): 24057,
#  ('view_apple', 'view_apple', 'view_huawei'): 24040,
#  ('view_samsung',
#   'view_samsung',
#   'view_xiaomi',
#   'view_samsung',
#   'view_samsung'): 23993,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_huawei'): 23955,
#  ('view_Unknown', 'view_baden'): 23954,
#  ('cart_apple', 'view_apple', 'cart_apple'): 23878,
#  ('view_sokolov', 'view_Unknown'): 23871,
#  ('view_artel', 'view_artel', 'view_artel', 'view_artel'): 23861,
#  ('view_bts', 'view_bts'): 23830,
#  ('view_apple', 'cart_apple', 'view_apple', 'cart_apple'): 23797,
#  ('view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente'): 23778,
#  ('view_huawei',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 23774,
#  ('view_Unknown', 'view_brw', 'view_brw'): 23727,
#  ('view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 23663,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_xiaomi',
#   'view_samsung'): 23624,
#  ('view_respect', 'view_Unknown', 'view_Unknown'): 23593,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_huawei'): 23575,
#  ('view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente'): 23525,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'cart_apple',
#   'purchase_apple'): 23516,
#  ('view_Unknown', 'view_Unknown', 'view_bosch'): 23487,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_huawei',
#   'view_huawei'): 23455,
#  ('view_oppo', 'view_oppo', 'view_oppo', 'view_oppo', 'view_oppo'): 23408,
#  ('view_beko', 'view_beko', 'view_beko'): 23388,
#  ('cart_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 23388,
#  ('view_Unknown', 'view_Unknown', 'view_Unknown', 'purchase_Unknown'): 23381,
#  ('view_xiaomi', 'view_Unknown', 'view_Unknown'): 23369,
#  ('cart_apple', 'cart_apple', 'purchase_apple'): 23364,
#  ('view_samsung', 'view_huawei', 'view_huawei', 'view_samsung'): 23360,
#  ('view_apple',
#   'view_apple',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 23310,
#  ('view_samsung',
#   'cart_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 23296,
#  ('view_apple', 'cart_apple', 'cart_apple', 'purchase_apple'): 23295,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_brw',
#   'view_Unknown'): 23211,
#  ('view_triangle', 'view_triangle', 'view_triangle'): 23147,
#  ('view_force', 'view_Unknown'): 23108,
#  ('view_hp', 'view_acer'): 23087,
#  ('view_apple', 'view_samsung', 'view_xiaomi'): 23079,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_brw',
#   'view_Unknown',
#   'view_Unknown'): 23036,
#  ('view_omabelle', 'view_omabelle'): 23009,
#  ('view_huawei',
#   'view_huawei',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 22979,
#  ('view_brw', 'view_brw', 'view_Unknown'): 22967,
#  ('view_starline', 'view_starline'): 22950,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 22947,
#  ('view_samsung', 'view_apple', 'view_apple', 'view_samsung'): 22942,
#  ('view_huawei', 'view_samsung', 'view_huawei'): 22941,
#  ('view_acer', 'view_acer', 'view_acer', 'view_acer', 'view_acer'): 22937,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'purchase_samsung'): 22927,
#  ('view_Unknown', 'view_bts', 'view_Unknown', 'view_Unknown'): 22920,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_samsung',
#   'view_xiaomi',
#   'view_xiaomi'): 22919,
#  ('view_janome',): 22915,
#  ('view_apple', 'view_oppo'): 22892,
#  ('view_jvc',): 22886,
#  ('view_apple', 'view_apple', 'view_xiaomi', 'view_xiaomi'): 22884,
#  ('view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown'): 22884,
#  ('view_brw',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 22867,
#  ('view_xiaomi', 'view_huawei', 'view_xiaomi', 'view_xiaomi'): 22858,
#  ('view_samsung',
#   'view_samsung',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 22847,
#  ('view_xiaomi', 'view_huawei', 'view_samsung'): 22815,
#  ('cart_samsung', 'cart_samsung', 'cart_samsung'): 22814,
#  ('view_Unknown', 'view_Unknown', 'view_respect'): 22811,
#  ('view_bosch', 'view_samsung'): 22786,
#  ('view_acer', 'view_acer', 'view_lenovo'): 22746,
#  ('view_Unknown', 'view_dauscher'): 22720,
#  ('cart_xiaomi', 'view_xiaomi', 'view_xiaomi'): 22689,
#  ('view_baden', 'view_respect'): 22680,
#  ('view_samsung', 'cart_samsung', 'cart_samsung', 'cart_samsung'): 22634,
#  ('view_xiaomi', 'cart_xiaomi', 'view_xiaomi', 'view_xiaomi'): 22587,
#  ('view_apple', 'view_apple', 'view_Unknown'): 22565,
#  ('view_hp', 'view_lenovo'): 22517,
#  ('view_hp', 'view_hp', 'view_hp', 'view_hp'): 22504,
#  ('view_Unknown',
#   'view_brw',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 22477,
#  ('view_apple', 'view_apple', 'view_samsung', 'view_apple'): 22473,
#  ('view_oneplus',): 22440,
#  ('view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 22431,
#  ('view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 22425,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_apple',
#   'view_apple'): 22416,
#  ('view_xiaomi', 'view_samsung', 'view_huawei'): 22409,
#  ('view_apple', 'view_apple', 'view_apple', 'view_xiaomi'): 22381,
#  ('view_saturn',): 22329,
#  ('view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 22325,
#  ('view_lg', 'view_samsung', 'view_samsung', 'view_samsung'): 22311,
#  ('view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente'): 22303,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 22275,
#  ('view_xiaomi', 'view_xiaomi', 'view_huawei', 'view_xiaomi'): 22273,
#  ('view_kapsen',): 22265,
#  ('cart_samsung', 'purchase_samsung', 'view_samsung', 'view_samsung'): 22242,
#  ('view_sv', 'view_sv', 'view_Unknown'): 22230,
#  ('view_Unknown', 'view_sv', 'view_sv'): 22228,
#  ('view_oppo', 'view_oppo', 'view_samsung'): 22177,
#  ('view_Unknown', 'view_Unknown', 'view_bts', 'view_Unknown'): 22148,
#  ('view_samsung',
#   'cart_samsung',
#   'purchase_samsung',
#   'view_samsung',
#   'view_samsung'): 22148,
#  ('view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown'): 22130,
#  ('view_Unknown', 'view_Unknown', 'view_Unknown', 'view_bts'): 22124,
#  ('view_bq',): 22095,
#  ('view_xiaomi',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 22082,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'purchase_samsung'): 22077,
#  ('view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 22067,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_huawei',
#   'view_huawei'): 22048,
#  ('view_respect', 'view_respect', 'view_Unknown'): 22025,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente'): 22021,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_samsung'): 21972,
#  ('view_canon',): 21946,
#  ('view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_lucente'): 21939,
#  ('view_huawei', 'view_xiaomi', 'view_huawei'): 21933,
#  ('view_acer', 'view_lenovo', 'view_lenovo'): 21914,
#  ('view_luminarc',): 21901,
#  ('view_samsung', 'view_apple', 'view_xiaomi'): 21880,
#  ('view_salamander',): 21839,
#  ('view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown'): 21789,
#  ('view_pioneer', 'view_Unknown'): 21755,
#  ('view_samsung', 'view_samsung', 'view_Unknown', 'view_Unknown'): 21753,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente'): 21737,
#  ('view_xiaomi', 'view_xiaomi', 'view_Unknown'): 21730,
#  ('cart_samsung', 'view_samsung', 'view_samsung', 'cart_samsung'): 21704,
#  ('view_Unknown', 'view_stels'): 21693,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_samsung',
#   'view_samsung'): 21671,
#  ('view_samsung',
#   'view_samsung',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_samsung'): 21652,
#  ('view_sv',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 21644,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_sv'): 21633,
#  ('view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown'): 21618,
#  ('view_samsung',
#   'cart_samsung',
#   'view_samsung',
#   'view_samsung',
#   'cart_samsung'): 21588,
#  ('view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_samsung',
#   'view_samsung'): 21577,
#  ('view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'cart_samsung',
#   'view_samsung'): 21573,
#  ('view_samsung', 'view_Unknown', 'view_Unknown', 'view_Unknown'): 21569,
#  ('view_samsung', 'view_samsung', 'view_huawei', 'view_xiaomi'): 21557,
#  ('view_strobbs',): 21556,
#  ('view_samsung', 'view_samsung', 'view_oppo', 'view_oppo'): 21520,
#  ('view_xiaomi',
#   'view_samsung',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 21471,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 21453,
#  ('view_polaris', 'view_polaris', 'view_polaris'): 21415,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 21409,
#  ('view_apple', 'view_samsung', 'view_apple', 'view_apple'): 21406,
#  ('view_Unknown', 'view_respect', 'view_respect'): 21392,
#  ('view_lg', 'view_lg', 'view_samsung', 'view_samsung'): 21380,
#  ('view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 21349,
#  ('view_xiaomi', 'view_xiaomi', 'view_xiaomi', 'view_apple'): 21341,
#  ('view_samsung', 'view_huawei', 'view_xiaomi', 'view_xiaomi'): 21312,
#  ('view_sony', 'view_samsung'): 21294,
#  ('view_huawei', 'view_samsung', 'view_xiaomi'): 21281,
#  ('view_apple', 'view_apple', 'cart_apple', 'cart_apple'): 21276,
#  ('view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'view_samsung',
#   'cart_samsung'): 21256,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'cart_apple',
#   'view_apple'): 21251,
#  ('view_samsung',
#   'view_xiaomi',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 21238,
#  ('view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente'): 21221,
#  ('view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente'): 21212,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 21197,
#  ('view_alteco',): 21194,
#  ('view_tefal', 'view_tefal', 'view_tefal'): 21152,
#  ('view_asus', 'view_acer'): 21147,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 21145,
#  ('view_huawei', 'view_xiaomi', 'view_samsung'): 21051,
#  ('view_cordiant', 'view_nokian'): 21021,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_samsung',
#   'view_xiaomi'): 21020,
# ...
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_huawei',
#   'view_samsung'): 19208,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_lg'): 19203,
#  ('view_meizu', 'view_meizu', 'view_meizu'): 19161,
#  ('view_lg', 'view_lg', 'view_lg', 'view_lg', 'view_lg', 'view_lg'): 19126,
#  ('view_lider', 'view_Unknown'): 19093,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei'): 19047,
#  ('view_fassen',): 19022,
#  ('view_Unknown', 'view_nike'): 19020,
#  ('view_nokian', 'view_nokian', 'view_nokian'): 19018,
#  ('view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'cart_samsung',
#   'purchase_samsung'): 19007,
#  ('view_Unknown', 'view_Unknown', 'view_brw', 'view_brw'): 19001,
#  ('view_samsung', 'view_samsung', 'view_lg', 'view_samsung'): 18977,
#  ('view_goodyear',): 18977,
#  ('view_Unknown', 'view_xiaomi', 'view_xiaomi'): 18974,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 18948,
#  ('view_samsung',
#   'view_apple',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 18912,
#  ('view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 18894,
#  ('view_haier', 'view_haier', 'view_haier'): 18888,
#  ('view_casio', 'view_casio', 'view_casio', 'view_casio'): 18886,
#  ('view_lenovo', 'view_asus'): 18884,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_brw',
#   'view_Unknown'): 18879,
#  ('view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente'): 18877,
#  ('view_dauscher', 'view_dauscher', 'view_dauscher', 'view_dauscher'): 18872,
#  ('view_ariston',): 18869,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_oppo'): 18831,
#  ('view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 18804,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'purchase_samsung',
#   'view_samsung'): 18789,
#  ('view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown'): 18775,
#  ('view_huawei', 'view_apple', 'view_apple'): 18771,
#  ('view_yasin',): 18764,
#  ('view_acer', 'view_acer', 'view_hp'): 18736,
#  ('view_indesit', 'view_samsung'): 18711,
#  ('view_redmond', 'view_redmond', 'view_redmond', 'view_redmond'): 18701,
#  ('view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 18677,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_brw',
#   'view_Unknown',
#   'view_Unknown'): 18672,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente'): 18663,
#  ('view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_lucente'): 18663,
#  ('view_samsung',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 18632,
#  ('view_Unknown', 'view_sony'): 18625,
#  ('view_oppo', 'view_apple'): 18616,
#  ('view_artel', 'view_samsung'): 18607,
#  ('view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente'): 18583,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_brw',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 18542,
#  ('view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_xiaomi'): 18470,
#  ('view_brw',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 18466,
#  ('view_xiaomi', 'view_apple', 'view_apple', 'view_apple'): 18444,
#  ('view_Unknown', 'view_samsung', 'view_samsung', 'view_samsung'): 18438,
#  ('view_huawei',
#   'view_huawei',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 18422,
#  ('view_alpine',): 18416,
#  ('view_acer', 'view_acer', 'view_asus'): 18364,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente'): 18329,
#  ('view_oppo', 'view_samsung', 'view_samsung', 'view_samsung'): 18323,
#  ('view_Unknown',
#   'view_bts',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 18310,
#  ('view_imperial',): 18299,
#  ('view_Unknown',
#   'view_brw',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 18278,
#  ('view_lucente', 'view_sokolov'): 18257,
#  ('view_samsung', 'view_lg', 'view_samsung', 'view_samsung'): 18248,
#  ('view_samsung',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei'): 18206,
#  ('view_sony', 'view_Unknown'): 18205,
#  ('view_samsung',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_samsung'): 18193,
#  ('view_brw', 'view_Unknown', 'view_brw'): 18191,
#  ('view_samsung',
#   'view_samsung',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 18177,
#  ('cart_huawei', 'view_huawei'): 18168,
#  ('view_lenovo',
#   'view_lenovo',
#   'view_lenovo',
#   'view_lenovo',
#   'view_lenovo'): 18154,
#  ('view_xiaomi', 'view_sony'): 18135,
#  ('view_brw', 'view_brw', 'view_Unknown', 'view_Unknown'): 18116,
#  ('view_samsung', 'view_xiaomi', 'view_xiaomi', 'view_huawei'): 18113,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'purchase_samsung',
#   'view_samsung'): 18112,
#  ('view_huawei', 'cart_huawei', 'view_huawei'): 18103,
#  ('view_sv', 'view_sv', 'view_sv'): 18087,
#  ('view_Unknown', 'view_lider'): 18062,
#  ('view_samsung', 'view_xiaomi', 'view_huawei', 'view_huawei'): 18060,
#  ('view_sokolov', 'view_Unknown', 'view_Unknown'): 18038,
#  ('view_Unknown', 'view_casio'): 18022,
#  ('view_vitek', 'view_polaris'): 17995,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 17961,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_samsung',
#   'view_samsung'): 17923,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 17870,
#  ('view_artel', 'view_Unknown'): 17867,
#  ('view_samsung', 'view_indesit'): 17862,
#  ('view_lucente',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_lucente'): 17851,
#  ('view_samsung',
#   'view_samsung',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 17850,
#  ('view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown'): 17849,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 17841,
#  ('view_harper',): 17835,
#  ('view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 17823,
#  ('view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown'): 17814,
#  ('view_samsung',
#   'view_samsung',
#   'purchase_samsung',
#   'view_samsung',
#   'view_samsung'): 17787,
#  ('view_apple', 'view_xiaomi', 'view_apple'): 17786,
#  ('view_oppo', 'view_xiaomi', 'view_xiaomi', 'view_xiaomi'): 17785,
#  ('view_asus', 'view_lenovo'): 17780,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_bts',
#   'view_Unknown',
#   'view_Unknown'): 17775,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_Unknown'): 17762,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'purchase_apple'): 17747,
#  ('view_makita',): 17741,
#  ('view_brw', 'view_brw', 'view_brw'): 17737,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_huawei'): 17724,
#  ('view_hansa', 'view_hansa'): 17705,
#  ('view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown'): 17702,
#  ('view_philips', 'view_philips', 'view_philips', 'view_philips'): 17676,
#  ('view_Unknown', 'view_Unknown', 'purchase_Unknown', 'view_Unknown'): 17675,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente'): 17666,
#  ('view_polaris', 'view_vitek'): 17626,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'cart_apple',
#   'view_apple',
#   'view_apple'): 17614,
#  ('view_Unknown', 'view_brw', 'view_brw', 'view_Unknown'): 17591,
#  ('view_lg', 'view_samsung', 'view_lg'): 17588,
#  ('view_samsung',
#   'view_samsung',
#   'view_huawei',
#   'view_huawei',
#   'view_samsung'): 17586,
#  ('view_moulinex',): 17578,
#  ('view_xiaomi', 'view_samsung', 'view_apple'): 17574,
#  ('view_sho-me',): 17530,
#  ('view_xiaomi', 'view_apple', 'view_xiaomi'): 17524,
#  ('view_samsung', 'view_samsung', 'view_samsung', 'view_lg', 'view_lg'): 17523,
#  ('view_xiaomi',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei',
#   'view_huawei'): 17511,
#  ('view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 17490,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'purchase_Unknown'): 17488,
#  ('cart_apple', 'view_apple', 'view_apple', 'view_apple', 'view_apple'): 17480,
#  ('view_delonghi',): 17454,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_huawei'): 17443,
#  ('cart_samsung', 'view_samsung', 'purchase_samsung', 'view_samsung'): 17437,
#  ('view_apple',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi'): 17424,
#  ('view_Unknown', 'view_Unknown', 'view_pioneer'): 17417,
#  ('view_apple',
#   'cart_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 17417,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente'): 17381,
#  ('view_samsung',
#   'view_huawei',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 17375,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple'): 17333,
#  ('view_tp-link',): 17300,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_bts'): 17296,
#  ('view_lg', 'view_lg', 'view_lg', 'view_samsung'): 17260,
#  ('view_sv',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 17251,
#  ('view_samsung',
#   'cart_samsung',
#   'view_samsung',
#   'purchase_samsung',
#   'view_samsung'): 17249,
#  ('view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente'): 17243,
#  ('view_omabelle', 'view_Unknown'): 17237,
#  ('view_force', 'view_force', 'view_force'): 17210,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 17191,
#  ('view_Unknown', 'view_sokolov', 'view_Unknown'): 17120,
#  ('view_apple', 'view_samsung', 'view_huawei'): 17116,
#  ('cart_apple', 'view_apple', 'cart_apple', 'view_apple'): 17100,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'cart_xiaomi'): 17095,
#  ('view_xiaomi', 'view_xiaomi', 'view_xiaomi', 'view_oppo'): 17086,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_bts',
#   'view_Unknown'): 17084,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_sv'): 17064,
#  ('view_ibox',): 17052,
#  ('view_apple', 'cart_apple', 'view_apple', 'cart_apple', 'view_apple'): 17040,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_huawei',
#   'view_xiaomi',
#   'view_xiaomi'): 17028,
#  ('cart_samsung', 'view_samsung', 'view_samsung', 'purchase_samsung'): 17025,
#  ('view_huawei',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 17023,
#  ('view_acer', 'view_hp', 'view_hp'): 16999,
#  ('view_samsung', 'view_samsung', 'view_bosch'): 16998,
#  ('view_janome', 'view_janome'): 16995,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_huawei',
#   'view_huawei'): 16986,
#  ('view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente'): 16978,
#  ('view_sv', 'view_Unknown', 'view_sv'): 16954,
#  ('view_dewalt',): 16945,
#  ('view_sv', 'view_sv', 'view_Unknown', 'view_Unknown'): 16927,
#  ('view_stels', 'view_Unknown', 'view_Unknown'): 16926,
#  ('view_rowenta', 'view_rowenta'): 16924,
#  ('view_samsung',
#   'cart_samsung',
#   'view_samsung',
#   'view_samsung',
#   'purchase_samsung'): 16917,
#  ('view_Unknown', 'view_lg'): 16914,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 16900,
#  ('view_Unknown', 'view_Unknown', 'view_sv', 'view_sv'): 16895,
#  ('view_chicco',): 16888,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'cart_xiaomi',
#   'view_xiaomi'): 16880,
#  ('view_sven',): 16863,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_xiaomi',
#   'view_samsung'): 16858,
#  ('view_apple',
#   'view_apple',
#   'view_apple',
#   'view_apple',
#   'purchase_apple',
#   'view_apple'): 16841,
#  ('view_oppo', 'view_oppo', 'view_huawei'): 16829,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown'): 16822,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 16821,
#  ('view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown'): 16821,
#  ('purchase_samsung', 'purchase_samsung'): 16802,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'purchase_samsung'): 16785,
#  ('view_acer',
#   'view_acer',
#   'view_acer',
#   'view_acer',
#   'view_acer',
#   'view_acer'): 16784,
#  ('view_apple',
#   'view_apple',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 16768,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'cart_samsung',
#   'view_samsung',
#   'view_samsung'): 16750,
#  ('view_samsung', 'purchase_samsung', 'purchase_samsung'): 16747,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown'): 16726,
#  ('view_lucente',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown'): 16718,
#  ('view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_xiaomi',
#   'view_huawei',
#   'view_huawei'): 16689,
#  ('view_samsung',
#   'view_huawei',
#   'view_huawei',
#   'view_samsung',
#   'view_samsung'): 16678,
#  ('view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown'): 16665,
#  ('view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_Unknown',
#   'view_lucente',
#   'view_Unknown'): 16660,
#  ('view_indesit', 'view_Unknown'): 16657,
#  ('view_kenwood', 'view_kenwood'): 16648,
#  ('view_Unknown', 'view_bosch', 'view_Unknown'): 16615,
#  ('view_lucente',
#   'view_Unknown',
#   'view_lucente',
#   'view_lucente',
#   'view_Unknown',
#   'view_Unknown'): 16581,
#  ('view_huawei', 'view_oppo', 'view_oppo'): 16563,
#  ('view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_xiaomi',
#   'view_samsung',
#   'view_samsung'): 16537,
#  ('view_force', 'view_stels', 'view_stels'): 16517,
#  ('view_epson',): 16507,
#  ('view_respect', 'view_Unknown', 'view_respect'): 16501,
#  ('view_huawei',
#   'view_huawei',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung',
#   'view_samsung'): 16493,
#  ...}

# %%
for freq, pat in business_patterns[:15]:
    if len(pat) > 1:
        antecedent = tuple(pat[:-1])
        consequent = pat[-1]
        if antecedent in pattern_dict:
            antecedent_freq = pattern_dict[antecedent]
            confidence = freq / antecedent_freq

            print(f"Pattern: {list(antecedent)} -> {consequent}")
            print(f"   Total Event  : {freq}")
            print(f"   Conversion Rate : {confidence:.2%} \n")
# Out:
# Pattern: ['view_samsung'] -> cart_samsung
#    Total Event  : 184926
#    Conversion Rate : 14.38%
#
# Pattern: ['view_samsung'] -> purchase_samsung
#    Total Event  : 148934
#    Conversion Rate : 11.58%
#
# Pattern: ['view_apple'] -> cart_apple
#    Total Event  : 135572
#    Conversion Rate : 13.53%
#
# Pattern: ['cart_samsung'] -> view_samsung
#    Total Event  : 127766
#    Conversion Rate : 68.77%
#
# Pattern: ['view_samsung', 'cart_samsung'] -> view_samsung
#    Total Event  : 127086
#    Conversion Rate : 68.72%
#
# Pattern: ['view_apple'] -> purchase_apple
#    Total Event  : 121342
#    Conversion Rate : 12.11%
#
# Pattern: ['cart_samsung'] -> purchase_samsung
#    Total Event  : 104910
#    Conversion Rate : 56.47%
#
# Pattern: ['view_samsung', 'cart_samsung'] -> purchase_samsung
#    Total Event  : 104409
#    Conversion Rate : 56.46%
#
# Pattern: ['view_samsung', 'view_samsung'] -> cart_samsung
#    Total Event  : 94500
#    Conversion Rate : 9.73%
#
# Pattern: ['cart_apple'] -> view_apple
#    Total Event  : 92655
#    Conversion Rate : 68.11%
#
# Pattern: ['view_apple', 'cart_apple'] -> view_apple
#    Total Event  : 92293
#    Conversion Rate : 68.08%

# %%
transitions = defaultdict(int)
for freq, pat in business_patterns[:30]:
    for i in range(len(pat) - 1):
        source = pat[i]
        target = pat[i+1]
        transitions[(source, target)] += freq
nodes = list(set([src for src, tgt in transitions.keys()] + [tgt for src, tgt in transitions.keys()]))
node_indices = {node: i for i, node in enumerate(nodes)}

# %%
sources = [node_indices[src] for src, tgt in transitions.keys()]
targets = [node_indices[tgt] for src, tgt in transitions.keys()]
values = list(transitions.values())

# %%
fig = go.Figure(data=[go.Sankey(
    node = dict(pad = 20,thickness = 20,line = dict(color = "black", width = 0.5),label = nodes,color = "lightblue"),
    link = dict(source = sources,target = targets,value = values,color = "rgba(173, 216, 230, 0.4)" )
    )])
fig.update_layout(title_text="Customer Journey Flow (E-Commerce)", font_size=12)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f29bc55b-ea71-4432-aae8-6be68a20809c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f29bc55b-ea71-4432-aae8-6be68a20809c")) {                    Plotly.newPlot(                        "f29bc55b-ea71-4432-aae8-6be68a20809c",                        [{"link":{"color":"rgba(173, 216, 230, 0.4)","source":[6,6,2,5,2,5,6,4,3,0,4,2,1],"target":[5,3,4,6,0,3,6,2,6,2,0,2,7],"value":[639639,313074,369676,446011,263885,270809,362430,184948,236497,162476,145051,130829,63784]},"node":{"color":"lightblue","label":["purchase_apple","view_xiaomi","view_apple","purchase_samsung","cart_apple","cart_samsung","view_samsung","cart_xiaomi"],"line":{"color":"black","width":0.5},"pad":20,"thickness":20},"type":"sankey"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}], ...
